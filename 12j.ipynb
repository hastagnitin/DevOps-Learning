# %%
file = open("data.txt", "r")

# %%
print(file.read())

# %%
file.close()

# %%
file = open("data.txt", "r")

# %%
print(file.read())
# Out:
# ram ram sare bhaia ne

# %%
file.close()

# %%
file = open("data.txt", "w")

# %%
file.write("This will cause an error because the file is opened in read mode.")
# Out:
# 65

# %%
file.close()
