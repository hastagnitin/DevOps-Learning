# %%
# Out:
# ['aman', 'raman', 'cherry', 'Grapes']

# %%
list1 = [1,2,3,4,5]
print(len(list1))
# Out:
# 5

# %%
list1 = list((1,2,3,4,5))
print(list1)
# Out:
# [1, 2, 3, 4, 5]

# %%
list1 = list((1,2,3,4,5))
print(list1.index(5))
# Out:
# 4

# %%
list1 = [10,20,30,4060]
list1.append(60)
print(list1)
# Out:
# [10, 20, 30, 4060, 60]

# %%
# Out:
# [10, 20, 30, 'Pu chandigarh', 40]

# %%
l1  = [1,2,3,4,5]
l3 = [6,7,8]
l1.extend(l3)
print(l1)
# Out:
# [1, 2, 3, 4, 5, 6, 7, 8]

# %%
l1 = [1,2,3,4,5,6]
print(l1.count(5))
# Out:
# 1

# %%
l1 = [1,2,3,4,5]
l2 = l1.copy()
print(l2)
# Out:
# [1, 2, 3, 4, 5]

# %%
l1 = [1,2,3,4,56]
l1.clear()
print(l1)
# Out:
# []

# %%
l1 = [1,2,3,4,56]
l1.remove(3)
print(l1)
# Out:
# [1, 2, 4, 56]

# %%
li = [1,2,3,4,5,6]
l1.pop()
print(l1)


fruits = ["apple","cherry","cherry","grapes","cherry"]
fruits.pop(3)
print(fruits)
# Out:
# [1, 2]
# ['apple', 'cherry', 'cherry', 'cherry']

# %%
list1 = ["aman","raman","cherry","Grapes"]
print(list1)

# %%
list1 = [10,20,30,40]
list1.insert(3,"Pu chandigarh")
print(list1)
# Out:
# [10, 20, 30, 'Pu chandigarh', 40]

# %%
l1 = [1,2,3,4,5]
l1.reverse()
print(l1)
# Out:
# [5, 4, 3, 2, 1]

# %%
li = [3,2,34,54,356,6]
li.sort()
print(li)
# Out:
# [2, 3, 6, 34, 54, 356]

# %%
l1= [3,1,2,3,4,6,4,5]
print(sorted(li))
# Out:
# [2, 3, 6, 34, 54, 356]

# %%
li = [10,20,30,40,50]
print(li[2:6])
# Out:
# [30, 40, 50]

# %%
l2 = [10,20,30,40,50,60]
slice2 = l2[-4:]
print(slice2)
# Out:
# [30, 40, 50, 60]
