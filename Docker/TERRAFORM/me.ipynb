# %%
import boto3


print("Boto3 Version:", boto3.__version__)


try:
    ec2 = boto3.client('ec2', region_name='ap-south-1')
    print("Boto3 ")
    
except Exception as e:
    print(" missing :", e)
# Out:
# Boto3 Version: 1.43.27
# Boto3

# %%
import boto3

# %%
s3 = boto3.client(
    "s3",
    aws_access_key_id="",
    aws_secret_access_key="",
    region_name="ap-south-1"
)

# %%
response = s3.list_buckets()
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 response = s3.list_buckets()
#
# File c:\Users\nitin\AppData\Local\Programs\Python\Python314\Lib\site-packages\botocore\client.py:606, in ClientCreator._create_api_method.<locals>._api_call(self, *args, **kwargs)
#     602     raise TypeError(
#     603         f"{py_operation_name}() only accepts keyword arguments."
#     604     )
#     605 # The "self" in this scope is referring to the BaseClient.
# --> 606 return self._make_api_call(operation_name, kwargs)
#
# File c:\Users\nitin\AppData\Local\Programs\Python\Python314\Lib\site-packages\botocore\context.py:123, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     121 if hook:
#     122     hook()
# --> 123 return func(*args, **kwargs)
#
# File c:\Users\nitin\AppData\Local\Programs\Python\Python314\Lib\site-packages\botocore\client.py:1094, in BaseClient._make_api_call(self, operation_name, api_params)
#    1090     error_code = request_context.get(
#    1091         'error_code_override'
#    1092     ) or error_info.get("Code")
#    1093     error_class = self.exceptions.from_code(error_code)
# -> 1094     raise error_class(parsed_response, operation_name)
#    1095 else:
#    1096     return parsed_response
#
# ClientError: An error occurred (AuthorizationHeaderMalformed) when calling the ListBuckets operation: The authorization header is malformed; a non-empty Access Key (AKID) must be provided in the credential.

# %%
print(response)

# %%
for i in response['Buckets']:
    print(i['Name'])
